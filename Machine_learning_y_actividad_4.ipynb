# %% [markdown]
# # **Reintroducción al Aprendizaje de Máquina**
#
# ![imagen](https://drive.google.com/uc?id=1tt5FoPGWtGkSrIuR4itna0ZNI4_FQBJe)
#
# <br>
#
# En clases pasadas hemos tratado:
# - ¿ Qué es Machine Learning?
# - Ejemplos de aplicación de Machine Learning en el mundo

# %% [markdown]
# ## ¿Qué es Machine Learning?
#
# a) Analizar y explorar datos
# b) Inteligencia Artificial
# c) El estudio de programas que aprenden en base a una experiencia
# d) Algoritmos estadísticos

# %% [markdown]
# **Respuesta: C**

# %% [markdown]
# ### **Los algoritmos de machine learning son capaces de generalizar a partir de ejemplos de una tarea:**
#
# - Ejemplo: un algoritmo de clasificación es capaz de "ver" imágenes etiquetadas en un set de datos de entrenamiento y aprender cómo aplicar estas etiquetas a nuevas imágenes jamás vistas anteriormente.
#
# ![imagen](https://drive.google.com/uc?id=1vW-AwxDX7TJx5K1OXOQ6uTJZIwTw-NQw)

# %% [markdown]
# ### # **_No todos los problemas se pueden resolver con la forma clásica de programación_**
#
# **Problema clásico**: ¿Cómo traigo datos de una base de datos relacional?
# **Problema nuevo**: Convertir voz humana a texto
#
# Debido a la gran complejidad de estos nuevos problemas, una serie de instrucciones (programa clásico) no basta para resolverlos de forma efectiva.

# %% [markdown]
# ## **Los modelos de Machine Learning son capaces de aprender mediante ejemplos**
#
# - Los algoritmos aprenden reglas a partir de **_ejemplos etiquetados_**
# - Un set de _ejemplos etiquetados_ utilizados para el aprendizaje es llamado: **_training data_** (datos de entrenamiento)
# - Las **_reglas_** aprendidas mediante los ejemplos deben poder **_generalizarse_** para reconocer correctamente o predecir nuevos ejemplos que no se incluyeron en el set de datos de entrenamiento.
#
# ![imagen](https://drive.google.com/uc?id=1EBsJ7wlcPjCLTPCoagCsJU0F8s_FZGRz)
#
# #### El Machine Learning nos ofrece la tecnología que nos permite aprender reglas de forma eficiente a partir de ejemplos etiquetados (training data). Esta, resulta en una forma más precisa y flexible que tener que programar "a mano" una serie de instrucciones.

# %% [markdown]
# #### **Problema básico de machine learning**
#
# Uno de los objetivos principales del Machine Learning es explorar cómo los computadores pueden programarse a sí mismos para realizar una tarea, mejorando su rendimiento automáticamente a medida ganan experiencia.
#
# Esta experiencia puede tomar forma en _datos_, en diferentes formatos o situaciones, como:
#
# - Ejemplos etiquetados: clasificar spam de correos electrónicos
# - Feedback de usuarios: clicks de un usuario en una página
# - Entorno inmediato: vehículos con piloto automático

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('9ydhDQaLAqM')

# %% [markdown]
# ### **Para resolver estos problemas, el machine learning se apoya en**:
# - **Métodos estadísticos**
#   - Inferir conclusiones a partir de los datos
#   - Estimar la certeza de las predicciones
# - **Ciencias de la computación**
#   - Arquitecturas computacionales a gran escala (Big data)
#   - Algoritmos capaces de capturar, manipular, indexar, combinar, obtener y realizar predicciones en base a datos
# - **Economía, biología, psicología**
#   - ¿Cómo puede un individuo o sistema mejorar eficientemente su rendimiento en un entorno determinado?
#   - ¿Qué es el aprendizaje? ¿Cómo puede optimizarse?

# %% [markdown]
# # **Aplicando Machine Learning**
#
# - Comprender conceptos básicos y flujo de trabajo
# - Como aplicar debidamente sus componentes y atributos
# - Aprender cómo aplicar algoritmos de machine learning utilizando Python y [Scikit-learn](https://scikit-learn.org/stable/index.html).

# %% [markdown]
# # Uno de los principales objetivos en la aplicación efectiva de algoritmos de Machine Learning es que sean capaces de **generalizar**. Esto hace referencia a la habilidad del algortimo de:
#
# a) Predecir perfectamente los datos de entrenamiento (training data)
# b) Hacer predicciones acertadas para nuevos objetos que no fueron vistos en la fase de entrenamiento
# c) Necesitar de sólo etiquetas en un set de datos de entrenamiento
# d) Encontrar clusters de objetos similares

# %% [markdown]
# **Respuesta: B**

# %% [markdown]
# # **Tipos de Aprendizaje de Máquina**
#
# - **_Supervisado_**: aprender a predecir los _valores ideales_ a partir de datos etiquetados
#   - **Clasificación**: los _valores ideales_ son clases discretas (un número de posibilidades finitas - ej: spam/no spam, masculino/femenino, camión/auto/motocicleta, limón/naranja/manzana/mandarina)
#   - **Regresión**: los los _valores ideales_ son valores continuos (ej: kilos, temperatura, tiempo en segundos)
#
# <br>
#
# ![img](https://drive.google.com/uc?id=1gZFNlfrvIcUObqYF4J_S-sjZbPsoITbm)
#
# ¿Quiénes clasifican las imágenes? ej: [Amazon Mechanical Turk](https://es.wikipedia.org/wiki/Amazon_Mechanical_Turk)
#
# - **_No Supervisado_**: encontrar estructuras en _datos no etiquetados_
#   - **Clustering**: encontrar grupos de instancias similares en los datos
#   - **Outlier detection** (datos atípicos): detección de patrones inusuales

# %% [markdown]
# # ¿Cuál de los siguientes son ejemplos de **Aprendizaje de Máquina Supervisado?**
#
# a) Analizar datos de ventas para encontrar grupos de consumidores con hábitos de compra similares
# b) Hacer recomendaciones online de películas basado en el rating que le dan los usuarios
# c) Un sistema de reconocimiento facial que fue entrenado utilizando etiquetas
# d) Un motor de búsqueda que utiliza los clicks de los usuarios en los resultados para saber cuáles son más reelevantes

# %% [markdown]
# **Respuesta: b, c, d**

# %% [markdown]
# # **¿Cómo abordo un problema de Machine Learning?**
#
# Flujo de trabajo básico:
#
# 1) **Representación** (Feature Representation): consiste en representar el problema de una forma en la que un computador pueda entenderlo. En esta fase se analiza el problema y selecciono:
#   - Atributos/Características/Propiedades que describen al/los objeto(s):
#   ej: pixeles de una imagen
#
#   - Tipo de algoritmo a utilizar: seleccionar el mejor modelo de machine learning
#   ej: clasificador de [k-vecinos más cercanos](https://www.youtube.com/watch?v=zBCcAtg3P4k)
#
# 2) **Evaluación** (Evaluation): permite chequear y comparar la eficiencia de los distintos modelos, para así saber (a ciencia cierta) qué modelos tienen buenos resultados y cuáles no. En esta fase selecciono:
#
#   - ¿Qué criterios distinguen a un buen modelo de uno malo?
#   ej: porcentaje de predicciones en un set de datos de prueba
#
# 3) **Optimización** (Optimization): en este paso buscamos por el modelo óptimo, que nos de los mejores resultados basándonos en la evaluación previa. En esta fase seleccionamos:
#   - La configuración/parámetros que den al modelo el mejor rendimiento.
#   ej: probar con una serie de valores como parámetros para un clasificador de k-vecinos más cercanos

# %% [markdown]
# # **Actividad 4**: _Creando un modelo de reconocimiento visual simple_  (Parte 1)
#
#
# Utilizando el [siguiente set de datos](https://drive.google.com/open?id=1Xvv4Vh_LscBP_jcTP46kJ2D0KLZveFJs), diseña y realiza un análisis exploratorio de los datos.
#
# Algunas preguntas que pueden ser de ayuda:
#
# - ¿Qué columnas posee el set de datos?
# - ¿Qué tipos datos existen en el set?
# - ¿Posee el set de datos valores nulos o datos faltantes?
# - ¿Qué datos entiendes y cuáles no?
# - ¿Podríamos respresentar algunos datos de forma distinta para comprenderlos mejor?
# - ¿Qué atributos/columnas crees nos puedan servir para clasificar los datos?
# - ¿Qué modelo de machine learning tendría mejores resultados según tu opinión? ¿Por qué?
